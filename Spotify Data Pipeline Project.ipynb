# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\asus\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\asus\anaconda3\lib\site-packages (from spotipy) (5.2.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\asus\anaconda3\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\asus\anaconda3\lib\site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="f58fe039ce684cdcb9ea28f5aeaffc02", client_secret="082d735f02c84b3bad52a204765e5947")

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/0sDahzOkMWOmLXfTMf2N4N"

# %%
playlist_URI=playlist_link.split("/")[-1]

# %%
data=sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]
# Out:
# {'added_at': '2024-11-24T19:46:17Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31yn33ajrpj5uzi6bc7u66v2w424'},
#   'href': 'https://api.spotify.com/v1/users/31yn33ajrpj5uzi6bc7u66v2w424',
#   'id': '31yn33ajrpj5uzi6bc7u66v2w424',
#   'type': 'user',
#   'uri': 'spotify:user:31yn33ajrpj5uzi6bc7u66v2w424'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': True,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'album',
#    'href': 'https://api.spotify.com/v1/albums/0hvT3yIEysuuvkK73vgdcW',
#    'id': '0hvT3yIEysuuvkK73vgdcW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d9985092cd88bffd97653b58',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d9985092cd88bffd97653b58',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d9985092cd88bffd97653b58',
#      'width': 64}],
#    'name': 'GNX',
#    'release_date': '2024-11-22',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:0hvT3yIEysuuvkK73vgdcW',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#      'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#      'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#      'name': 'Kendrick Lamar',
#      'type': 'artist',
#      'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#    'total_tracks': 12},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#     'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#     'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#     'name': 'Kendrick Lamar',
#     'type': 'artist',
#     'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#   'disc_number': 1,
#   'track_number': 2,
#   'duration_ms': 157992,
#   'external_ids': {'isrc': 'USUG12408494'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0nj9Bq5sHDiTxSHunhgkFb'},
#   'href': 'https://api.spotify.com/v1/tracks/0nj9Bq5sHDiTxSHunhgkFb',
#   'id': '0nj9Bq5sHDiTxSHunhgkFb',
#   'name': 'squabble up',
#   'popularity': 90,
#   'uri': 'spotify:track:0nj9Bq5sHDiTxSHunhgkFb',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
len(data['items'])
# Out:
# 100

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0hvT3yIEysuuvkK73vgdcW'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'GNX'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-11-22'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 12

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list[0]
# Out:
# {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#  'name': 'GNX',
#  'release_date': '2024-11-22',
#  'total_tracks': 12,
#  'url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'}

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#   'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#   'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'name': 'Kendrick Lamar',
#   'type': 'artist',
#   'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}]

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '1jiZvw42D4oquLl24x2VWV',
#   'artist_name': 'Lefty Gunplay',
#   'external_url': 'https://api.spotify.com/v1/artists/1jiZvw42D4oquLl24x2VWV'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '4VHa48wXlsDA2vWfgIi7cX',
#   'artist_name': 'Dody6',
#   'external_url': 'https://api.spotify.com/v1/artists/4VHa48wXlsDA2vWfgIi7cX'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '4qQgMu20UfwRFHFfyMIrTH',
#   'artist_name': 'Senzei',
#   'external_url': 'https://api.spotify.com/v1/artists/4qQgMu20UfwRFHFfyMIrTH'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '4qQgMu20UfwRFHFfyMIrTH',
#   'artist_name': 'Senzei',
#   'external_url': 'https://api.spotify.com/v1/artists/4qQgMu20UfwRFHFfyMIrTH'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '6cUpFVxDYWed9WxtC4QgC5',
#   'artist_name': 'Wallie the Sensei',
#   'external_url': 'https://api.spotify.com/v1/artists/6cUpFVxDYWed9WxtC4QgC5'},
#  {'artist_id': '7J5UWTbsUFjoSQZQCQCqbQ',
#   'artist_name': 'Siete7x',
#   'external_url': 'https://api.spotify.com/v1/artists/7J5UWTbsUFjoSQZQCQCqbQ'},
#  {'artist_id': '757aE44tKEUQEqRuT6GnEB',
#   'artist_name': 'Roddy Ricch',
#   'external_url': 'https://api.spotify.com/v1/artists/757aE44tKEUQEqRuT6GnEB'},
#  {'artist_id': '4qQgMu20UfwRFHFfyMIrTH',
#   'artist_name': 'Senzei',
#   'external_url': 'https://api.spotify.com/v1/artists/4qQgMu20UfwRFHFfyMIrTH'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '4qQgMu20UfwRFHFfyMIrTH',
#   'artist_name': 'Senzei',
#   'external_url': 'https://api.spotify.com/v1/artists/4qQgMu20UfwRFHFfyMIrTH'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '6fqjJNsLs7g6F3PXy01Xnw',
#   'artist_name': 'AzChike',
#   'external_url': 'https://api.spotify.com/v1/artists/6fqjJNsLs7g6F3PXy01Xnw'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '50DchbKTiJU56SYmIRSJCI',
#   'artist_name': 'Hitta J3',
#   'external_url': 'https://api.spotify.com/v1/artists/50DchbKTiJU56SYmIRSJCI'},
#  {'artist_id': '1q2nUylEqrRJkiDkXa39Mw',
#   'artist_name': 'YoungThreat',
#   'external_url': 'https://api.spotify.com/v1/artists/1q2nUylEqrRJkiDkXa39Mw'},
#  {'artist_id': '27OdVby2oeFjM1C5XvC3hC',
#   'artist_name': 'Peysoh',
#   'external_url': 'https://api.spotify.com/v1/artists/27OdVby2oeFjM1C5XvC3hC'},
#  {'artist_id': '4qQgMu20UfwRFHFfyMIrTH',
#   'artist_name': 'Senzei',
#   'external_url': 'https://api.spotify.com/v1/artists/4qQgMu20UfwRFHFfyMIrTH'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '4qQgMu20UfwRFHFfyMIrTH',
#   'artist_name': 'Senzei',
#   'external_url': 'https://api.spotify.com/v1/artists/4qQgMu20UfwRFHFfyMIrTH'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'external_url': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '3y2cIKLjiOlp1Np37WiUdH',
#   'artist_name': 'Shaboozey',
#   'external_url': 'https://api.spotify.com/v1/artists/3y2cIKLjiOlp1Np37WiUdH'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '7tvffsY7pqTm6xQXL9J5nu',
#   'artist_name': 'pqKD',
#   'external_url': 'https://api.spotify.com/v1/artists/7tvffsY7pqTm6xQXL9J5nu'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'external_url': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://api.spotify.com/v1/artists/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '3DbwFQlvLxRSi2uX8mf81A',
#   'artist_name': 'Sexyy Red',
#   'external_url': 'https://api.spotify.com/v1/artists/3DbwFQlvLxRSi2uX8mf81A'},
#  {'artist_id': '55Aa2cqylxrFIXC767Z865',
#   'artist_name': 'Lil Wayne',
#   'external_url': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865'},
#  {'artist_id': '4iHNK0tOyZPYnBU7nGAgpQ',
#   'artist_name': 'Mariah Carey',
#   'external_url': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://api.spotify.com/v1/artists/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '3DbwFQlvLxRSi2uX8mf81A',
#   'artist_name': 'Sexyy Red',
#   'external_url': 'https://api.spotify.com/v1/artists/3DbwFQlvLxRSi2uX8mf81A'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'external_url': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_url': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '3l9G1G9MxH6DaRhwLklaf5',
#   'artist_name': 'Oscar Maydon',
#   'external_url': 'https://api.spotify.com/v1/artists/3l9G1G9MxH6DaRhwLklaf5'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'external_url': 'https://api.spotify.com/v1/artists/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '6YVMFz59CuY7ngCxTxjpxE',
#   'artist_name': 'aespa',
#   'external_url': 'https://api.spotify.com/v1/artists/6YVMFz59CuY7ngCxTxjpxE'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'external_url': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '46UMQ0cW8ToR8egkBRwAxZ',
#   'artist_name': 'Cynthia Erivo',
#   'external_url': 'https://api.spotify.com/v1/artists/46UMQ0cW8ToR8egkBRwAxZ'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '57LYzLEk2LcFghVwuWbcuS',
#   'artist_name': 'Summer Walker',
#   'external_url': 'https://api.spotify.com/v1/artists/57LYzLEk2LcFghVwuWbcuS'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '45TgXXqMDdF8BkjA83OM7z',
#   'artist_name': 'Rod Wave',
#   'external_url': 'https://api.spotify.com/v1/artists/45TgXXqMDdF8BkjA83OM7z'},
#  {'artist_id': '2FXC3k01G6Gw61bmprjgqS',
#   'artist_name': 'Hozier',
#   'external_url': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'external_url': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '5lwmRuXgjX8xIwlnauTZIP',
#   'artist_name': 'Romeo Santos',
#   'external_url': 'https://api.spotify.com/v1/artists/5lwmRuXgjX8xIwlnauTZIP'},
#  {'artist_id': '4QvgGvpgzgyUOo8Yp8LDm9',
#   'artist_name': 'Mrs. GREEN APPLE',
#   'external_url': 'https://api.spotify.com/v1/artists/4QvgGvpgzgyUOo8Yp8LDm9'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp',
#   'artist_name': 'Metro Boomin',
#   'external_url': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'external_url': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '67FB4n52MgexGQIG8s0yUH',
#   'artist_name': 'Lola Young',
#   'external_url': 'https://api.spotify.com/v1/artists/67FB4n52MgexGQIG8s0yUH'},
#  {'artist_id': '38EmEgXkgK51MT2tPY0EoC',
#   'artist_name': 'Bobby Helms',
#   'external_url': 'https://api.spotify.com/v1/artists/38EmEgXkgK51MT2tPY0EoC'},
#  {'artist_id': '1GxkXlMwML1oSg5eLPiAz3',
#   'artist_name': 'Michael Bublé',
#   'external_url': 'https://api.spotify.com/v1/artists/1GxkXlMwML1oSg5eLPiAz3'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'external_url': 'https://api.spotify.com/v1/artists/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '1iCnM8foFssWlPRLfAbIwo',
#   'artist_name': 'Gigi Perez',
#   'external_url': 'https://api.spotify.com/v1/artists/1iCnM8foFssWlPRLfAbIwo'},
#  {'artist_id': '3BmGtnKgCSGYIUhmivXKWX',
#   'artist_name': 'Kelly Clarkson',
#   'external_url': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX'},
#  {'artist_id': '0pWR7TsFhvSCnbmHDjWgrE',
#   'artist_name': 'Creepy Nuts',
#   'external_url': 'https://api.spotify.com/v1/artists/0pWR7TsFhvSCnbmHDjWgrE'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'external_url': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '4GGfAshSkqoxpZdoaHm7ky',
#   'artist_name': 'ERNEST',
#   'external_url': 'https://api.spotify.com/v1/artists/4GGfAshSkqoxpZdoaHm7ky'},
#  {'artist_id': '4sj6D0zlMOl25nprDJBiU9',
#   'artist_name': 'Andy Williams',
#   'external_url': 'https://api.spotify.com/v1/artists/4sj6D0zlMOl25nprDJBiU9'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '3bO19AOone0ubCsfDXDtYt',
#   'artist_name': 'Myles Smith',
#   'external_url': 'https://api.spotify.com/v1/artists/3bO19AOone0ubCsfDXDtYt'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://api.spotify.com/v1/artists/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '3aQeKQSyrW4qWr35idm0cy',
#   'artist_name': 'T-Pain',
#   'external_url': 'https://api.spotify.com/v1/artists/3aQeKQSyrW4qWr35idm0cy'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'external_url': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '4cPHsZM98sKzmV26wlwD2W',
#   'artist_name': 'Brenda Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/4cPHsZM98sKzmV26wlwD2W'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://api.spotify.com/v1/artists/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'external_url': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '687cZJR45JO7jhk1LHIbgq',
#   'artist_name': 'Tems',
#   'external_url': 'https://api.spotify.com/v1/artists/687cZJR45JO7jhk1LHIbgq'},
#  {'artist_id': '5f7VJjfbwm532GiveGC0ZK',
#   'artist_name': 'Lil Baby',
#   'external_url': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'external_url': 'https://api.spotify.com/v1/artists/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '0IwZVmMMGE7nNXS7vN9SIo',
#   'artist_name': 'MISAMO',
#   'external_url': 'https://api.spotify.com/v1/artists/0IwZVmMMGE7nNXS7vN9SIo'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://api.spotify.com/v1/artists/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '5lpH0xAS4fVfLkACg9DAuM',
#   'artist_name': 'Wham!',
#   'external_url': 'https://api.spotify.com/v1/artists/5lpH0xAS4fVfLkACg9DAuM'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '5f7VJjfbwm532GiveGC0ZK',
#   'artist_name': 'Lil Baby',
#   'external_url': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK'},
#  {'artist_id': '3tVQdUvClmAT7URs9V3rsp',
#   'artist_name': 'Wizkid',
#   'external_url': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp'},
#  {'artist_id': '3a1tBryiczPAZpgoZN9Rzg',
#   'artist_name': 'Asake',
#   'external_url': 'https://api.spotify.com/v1/artists/3a1tBryiczPAZpgoZN9Rzg'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp',
#   'artist_name': 'Metro Boomin',
#   'external_url': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '718COspgdWOnwOFpJHRZHS',
#   'artist_name': 'Luke Combs',
#   'external_url': 'https://api.spotify.com/v1/artists/718COspgdWOnwOFpJHRZHS'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://api.spotify.com/v1/artists/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '3tVQdUvClmAT7URs9V3rsp',
#   'artist_name': 'Wizkid',
#   'external_url': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'external_url': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '20wkVLutqVOYrc0kxFs7rA',
#   'artist_name': 'Daniel Caesar',
#   'external_url': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '2RQXRUsr4IW1f3mKyKsy4B',
#   'artist_name': 'Noah Kahan',
#   'external_url': 'https://api.spotify.com/v1/artists/2RQXRUsr4IW1f3mKyKsy4B'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'external_url': 'https://api.spotify.com/v1/artists/7CvTknweLr9feJtRGrpDBy'},
#  {'artist_id': '1Yj5Xey7kTwvZla8sqdsdE',
#   'artist_name': 'Cris Mj',
#   'external_url': 'https://api.spotify.com/v1/artists/1Yj5Xey7kTwvZla8sqdsdE'},
#  {'artist_id': '4QvgGvpgzgyUOo8Yp8LDm9',
#   'artist_name': 'Mrs. GREEN APPLE',
#   'external_url': 'https://api.spotify.com/v1/artists/4QvgGvpgzgyUOo8Yp8LDm9'},
#  {'artist_id': '1WaFQSHVGZQJTbf0BdxdNo',
#   'artist_name': 'Tommy Richman',
#   'external_url': 'https://api.spotify.com/v1/artists/1WaFQSHVGZQJTbf0BdxdNo'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://api.spotify.com/v1/artists/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '49e4v89VmlDcFCMyDv9wQ9',
#   'artist_name': 'Dean Martin',
#   'external_url': 'https://api.spotify.com/v1/artists/49e4v89VmlDcFCMyDv9wQ9'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id name release_date  total_tracks  \
# 0  0hvT3yIEysuuvkK73vgdcW  GNX   2024-11-22            12
# 1  0hvT3yIEysuuvkK73vgdcW  GNX   2024-11-22            12
# 2  0hvT3yIEysuuvkK73vgdcW  GNX   2024-11-22            12
# 3  0hvT3yIEysuuvkK73vgdcW  GNX   2024-11-22            12
# 4  0hvT3yIEysuuvkK73vgdcW  GNX   2024-11-22            12
#
#                                                  url
# 0  https://open.spotify.com/album/0hvT3yIEysuuvkK...
# 1  https://open.spotify.com/album/0hvT3yIEysuuvkK...
# 2  https://open.spotify.com/album/0hvT3yIEysuuvkK...
# 3  https://open.spotify.com/album/0hvT3yIEysuuvkK...
# 4  https://open.spotify.com/album/0hvT3yIEysuuvkK...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
# 3  7tYKF4w9nC0nq9CsPZTHyP             SZA
# 5  1jiZvw42D4oquLl24x2VWV   Lefty Gunplay
# 7  4VHa48wXlsDA2vWfgIi7cX           Dody6
# 9  4qQgMu20UfwRFHFfyMIrTH          Senzei
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/2YZyLoL8N0W...
# 3  https://api.spotify.com/v1/artists/7tYKF4w9nC0...
# 5  https://api.spotify.com/v1/artists/1jiZvw42D4o...
# 7  https://api.spotify.com/v1/artists/4VHa48wXlsD...
# 9  https://api.spotify.com/v1/artists/4qQgMu20Ufw...

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                     song_name  duration_ms  \
# 0  0nj9Bq5sHDiTxSHunhgkFb                   squabble up       157992
# 1  5gOfC9UzZQzTyShqPMrpjT             wacced out murals       317092
# 2  45J4avUb9Ni0bnETYaYFVJ             luther (with sza)       177598
# 3  0aB0v4027ukVziUGwVGYpG  tv off (feat. lefty gunplay)       220690
# 4  5S8VwnB4sLi6W0lYTWYylu         hey now (feat. dody6)       217478
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0nj9Bq5sHDiTxSH...          90
# 1  https://open.spotify.com/track/5gOfC9UzZQzTySh...          87
# 2  https://open.spotify.com/track/45J4avUb9Ni0bnE...          89
# 3  https://open.spotify.com/track/0aB0v4027ukVziU...          90
# 4  https://open.spotify.com/track/5S8VwnB4sLi6W0l...          86
#
#              song_added                album_id               artist_id
# 0  2024-11-24T19:46:17Z  0hvT3yIEysuuvkK73vgdcW  2YZyLoL8N0Wb9xBt1NhZWg
# 1  2024-11-24T19:46:17Z  0hvT3yIEysuuvkK73vgdcW  2YZyLoL8N0Wb9xBt1NhZWg
# 2  2024-11-24T19:46:17Z  0hvT3yIEysuuvkK73vgdcW  2YZyLoL8N0Wb9xBt1NhZWg
# 3  2024-11-24T19:46:17Z  0hvT3yIEysuuvkK73vgdcW  2YZyLoL8N0Wb9xBt1NhZWg
# 4  2024-11-24T19:46:17Z  0hvT3yIEysuuvkK73vgdcW  2YZyLoL8N0Wb9xBt1NhZWg

# %%
album_df.head()
# Out:
#                   album_id                  name release_date  total_tracks  \
# 0   0hvT3yIEysuuvkK73vgdcW                   GNX   2024-11-22            12
# 6   65C6VNtY2N84VWLDukJFyA             Area Code   2024-05-17             1
# 8   5ShfsQaqUkrIt4GL4fu4VS  Proceed With Caution   2023-11-10             4
# 10  7sm1Y7rzrW8nWjXpa2BGpX              Pop Girl   2020-06-19             1
# 12  2IYQwwgxgOIn7t3iF6ufFD                  APT.   2024-10-18             1
#
#                                                   url
# 0   https://open.spotify.com/album/0hvT3yIEysuuvkK...
# 6   https://open.spotify.com/album/65C6VNtY2N84VWL...
# 8   https://open.spotify.com/album/5ShfsQaqUkrIt4G...
# 10  https://open.spotify.com/album/7sm1Y7rzrW8nWjX...
# 12  https://open.spotify.com/album/2IYQwwgxgOIn7t3...

# %%
album_df['release_date']=pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
print(len(album_df))
print(len(song_df))
print(len(artist_df))
# Out:
# 74
# 100
# 77
